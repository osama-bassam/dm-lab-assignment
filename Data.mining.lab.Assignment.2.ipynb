# %% [markdown]
# # Assignment 2
# # Data mining lab solved by <span style="color: blue;">osama bassam yousef Ali</span>

# %% [markdown]
# # Assignment 2
#
# implement a naïve Bayes classifier for a binary classification problem. Your classifier should be able to predict whether a given Weight and Colour are Banana or Apple.
#
# dataset name: fruits_Ass.csv
#
# To do this, you will need to implement the following three steps:
#
# training (size = 0.70)
#
# predicting
#
# evaluatetion (confusion_matrix, accuracy_score)

# %%
import pandas as pd
dataset = pd.read_csv('https://github.com/osama-bassam/data-mining-data/files/13965660/fruits_Ass.csv')
dataset
# Out:
#     Weight  Colour   Label
# 0      303       3  Banana
# 1      370       1   Apple
# 2      298       3  Banana
# 3      277       3  Banana
# 4      377       4   Apple
# 5      299       3  Banana
# 6      382       1   Apple
# 7      374       4   Apple
# 8      303       4  Banana
# 9      309       3  Banana
# 10     359       1   Apple
# 11     366       1   Apple
# 12     311       3  Banana
# 13     302       3  Banana
# 14     373       4   Apple
# 15     305       3  Banana
# 16     371       3   Apple

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
X = dataset.drop('Label' , axis = 1)
y = dataset['Label']
#from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 0) 
#from sklearn.naive_bayes import GaussianNB
#classifier = GaussianNB()
classifier.fit(X_train, y_train)  # classifier = GaussianNB()
y_pred = classifier.predict(X_test)
classifier.predict([[369,4]])
ac = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test, y_pred)
result=classification_report(y_test, y_pred)
print(ac)
print(cm)
print(result)
# Out:
# 0.8333333333333334
# [[3 0]
#  [1 2]]
#               precision    recall  f1-score   support
#
#        Apple       0.75      1.00      0.86         3
#       Banana       1.00      0.67      0.80         3
#
#     accuracy                           0.83         6
#    macro avg       0.88      0.83      0.83         6
# weighted avg       0.88      0.83      0.83         6
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
